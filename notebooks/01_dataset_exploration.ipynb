# %%
import sys
print(sys.version)
# Out:
# 3.11.5 (main, Sep 11 2023, 13:54:46) [GCC 11.2.0]

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# /homes/ebernini
# ['.bash_logout', 'examples.desktop', '.bashrc', '.profile', '.cache', '.lesshst', '.bash_history', 'cvcs2026', '.local', 'jupyter_cvcs.sh', '.ipython', '.npm', '.jupyter', '.ipynb_checkpoints', '.vscode-server', '.wget-hsts', '.dotnet', '.python_history', 'project']

# %%
import networkx as nx
import matplotlib.pyplot as plt

G = nx.Graph()
G.add_edge("Kitchen", "Living Room")

nx.draw(G, with_labels=True)
plt.show()
